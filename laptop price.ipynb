# %%
import pandas as pd           #https://www.kaggle.com/datasets/akashlal72/laptop-price-prediction(Dataset)
import seaborn as sns
df=pd.read_csv('laptop_data.csv')
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.Company.unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'Chuwi', 'MSI',
#        'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %%
df['Company'].value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
import matplotlib.pyplot as plt
sns.barplot(df['Company'],df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Company'] = le.fit_transform(df['Company'])

# %%
df
# Out:
#       Unnamed: 0  Company            TypeName  Inches  \
# 0              0        1           Ultrabook    13.3
# 1              1        1           Ultrabook    13.3
# 2              2        7            Notebook    15.6
# 3              3        1           Ultrabook    15.4
# 4              4        1           Ultrabook    13.3
# ...          ...      ...                 ...     ...
# 1298        1298       10  2 in 1 Convertible    14.0
# 1299        1299       10  2 in 1 Convertible    13.3
# 1300        1300       10            Notebook    14.0
# 1301        1301        7            Notebook    15.6
# 1302        1302        2            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df
# Out:
#       Unnamed: 0  Company            TypeName  Inches  \
# 0              0        1           Ultrabook    13.3
# 1              1        1           Ultrabook    13.3
# 2              2        7            Notebook    15.6
# 3              3        1           Ultrabook    15.4
# 4              4        1           Ultrabook    13.3
# ...          ...      ...                 ...     ...
# 1298        1298       10  2 in 1 Convertible    14.0
# 1299        1299       10  2 in 1 Convertible    13.3
# 1300        1300       10            Notebook    14.0
# 1301        1301        7            Notebook    15.6
# 1302        1302        2            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)   #irrelevant col

# %%
df
# Out:
#       Company            TypeName  Inches  \
# 0           1           Ultrabook    13.3
# 1           1           Ultrabook    13.3
# 2           7            Notebook    15.6
# 3           1           Ultrabook    15.4
# 4           1           Ultrabook    13.3
# ...       ...                 ...     ...
# 1298       10  2 in 1 Convertible    14.0
# 1299       10  2 in 1 Convertible    13.3
# 1300       10            Notebook    14.0
# 1301        7            Notebook    15.6
# 1302        2            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df.TypeName.unique()
# Out:
# array(['Ultrabook', 'Notebook', 'Netbook', 'Gaming', '2 in 1 Convertible',
#        'Workstation'], dtype=object)

# %%
df.TypeName.value_counts()
# Out:
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: TypeName, dtype: int64

# %%
import matplotlib.pyplot as plt
sns.barplot(df['TypeName'],df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
for i in range(1303):
    if df['TypeName'][i]=='Notebook':
        df['TypeName'][i]=0
    elif df['TypeName'][i]=='Workstation':
        df['TypeName'][i]=1
    elif df['TypeName'][i]=='Gaming':
        df['TypeName'][i]=2
    elif df['TypeName'][i]=='2 in 1 Convertible':
        df['TypeName'][i]=3
    elif df['TypeName'][i]=='Ultrabook':
        df['TypeName'][i]=4
    else:
        df['TypeName'][i]=5
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df
# Out:
#       Company TypeName  Inches                            ScreenResolution  \
# 0           1        4    13.3          IPS Panel Retina Display 2560x1600
# 1           1        4    13.3                                    1440x900
# 2           7        0    15.6                           Full HD 1920x1080
# 3           1        4    15.4          IPS Panel Retina Display 2880x1800
# 4           1        4    13.3          IPS Panel Retina Display 2560x1600
# ...       ...      ...     ...                                         ...
# 1298       10        3    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299       10        3    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300       10        0    14.0                                    1366x768
# 1301        7        0    15.6                                    1366x768
# 1302        2        0    15.6                                    1366x768
#
# ...

# %%
df.ScreenResolution.unique()
# Out:
# array(['IPS Panel Retina Display 2560x1600', '1440x900',
#        'Full HD 1920x1080', 'IPS Panel Retina Display 2880x1800',
#        '1366x768', 'IPS Panel Full HD 1920x1080',
#        'IPS Panel Retina Display 2304x1440',
#        'IPS Panel Full HD / Touchscreen 1920x1080',
#        'Full HD / Touchscreen 1920x1080',
#        'Touchscreen / Quad HD+ 3200x1800',
#        'IPS Panel Touchscreen 1920x1200', 'Touchscreen 2256x1504',
#        'Quad HD+ / Touchscreen 3200x1800', 'IPS Panel 1366x768',
#        'IPS Panel 4K Ultra HD / Touchscreen 3840x2160',
#        'IPS Panel Full HD 2160x1440',
#        '4K Ultra HD / Touchscreen 3840x2160', 'Touchscreen 2560x1440',
#        '1600x900', 'IPS Panel 4K Ultra HD 3840x2160',
#        '4K Ultra HD 3840x2160', 'Touchscreen 1366x768',
#        'IPS Panel Full HD 1366x768', 'IPS Panel 2560x1440',
#        'IPS Panel Full HD 2560x1440',
#        'IPS Panel Retina Display 2736x1824', 'Touchscreen 2400x1600',
# ...

# %%
df['IPS']='null'
str='IPS'
for i in range(1303):
    if str in df.ScreenResolution[i]:
        df['IPS'][i]=1
    else:
        df['IPS'][i]=0
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
df
# Out:
#       Company TypeName  Inches                            ScreenResolution  \
# 0           1        4    13.3          IPS Panel Retina Display 2560x1600
# 1           1        4    13.3                                    1440x900
# 2           7        0    15.6                           Full HD 1920x1080
# 3           1        4    15.4          IPS Panel Retina Display 2880x1800
# 4           1        4    13.3          IPS Panel Retina Display 2560x1600
# ...       ...      ...     ...                                         ...
# 1298       10        3    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299       10        3    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300       10        0    14.0                                    1366x768
# 1301        7        0    15.6                                    1366x768
# 1302        2        0    15.6                                    1366x768
#
# ...

# %%
df['x_axis']=0
df['y_axis']=0
a=df.ScreenResolution.str.split('x')
for i in range(1303):
    df['x_axis'][i]=a[i][0]
    df['y_axis'][i]=a[i][1]
df
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Shreya\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
for i in range(1303):
    df['x_axis'][i]=df['x_axis'][i][-4:]

# %%
df
# Out:
#       Company TypeName  Inches                            ScreenResolution  \
# 0           1        4    13.3          IPS Panel Retina Display 2560x1600
# 1           1        4    13.3                                    1440x900
# 2           7        0    15.6                           Full HD 1920x1080
# 3           1        4    15.4          IPS Panel Retina Display 2880x1800
# 4           1        4    13.3          IPS Panel Retina Display 2560x1600
# ...       ...      ...     ...                                         ...
# 1298       10        3    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299       10        3    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300       10        0    14.0                                    1366x768
# 1301        7        0    15.6                                    1366x768
# 1302        2        0    15.6                                    1366x768
#
# ...

# %%
df['hd+']=0
for i in range(1303):
    if 'HD+' in df['ScreenResolution'][i]:
        df['hd+'][i]=1
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df['hd+']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1298    0
# 1299    1
# 1300    0
# 1301    0
# 1302    0
# Name: hd+, Length: 1303, dtype: int64

# %%
import seaborn as sns
sns.barplot(df['hd+'],df['Price'])
# Out:
# <AxesSubplot:xlabel='hd+', ylabel='Price'>

# %% [markdown]
# ## Significant effect of hd+ on price, hence we can create a column for it

# %%
df
# Out:
#       Company TypeName  Inches                            ScreenResolution  \
# 0           1        4    13.3          IPS Panel Retina Display 2560x1600
# 1           1        4    13.3                                    1440x900
# 2           7        0    15.6                           Full HD 1920x1080
# 3           1        4    15.4          IPS Panel Retina Display 2880x1800
# 4           1        4    13.3          IPS Panel Retina Display 2560x1600
# ...       ...      ...     ...                                         ...
# 1298       10        3    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299       10        3    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300       10        0    14.0                                    1366x768
# 1301        7        0    15.6                                    1366x768
# 1302        2        0    15.6                                    1366x768
#
# ...

# %%
df['retina']=0
for i in range(1303):
    if 'Retina Display' in df['ScreenResolution'][i]:
        df['retina'][i]=1
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df
# Out:
#       Company TypeName  Inches                            ScreenResolution  \
# 0           1        4    13.3          IPS Panel Retina Display 2560x1600
# 1           1        4    13.3                                    1440x900
# 2           7        0    15.6                           Full HD 1920x1080
# 3           1        4    15.4          IPS Panel Retina Display 2880x1800
# 4           1        4    13.3          IPS Panel Retina Display 2560x1600
# ...       ...      ...     ...                                         ...
# 1298       10        3    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299       10        3    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300       10        0    14.0                                    1366x768
# 1301        7        0    15.6                                    1366x768
# 1302        2        0    15.6                                    1366x768
#
# ...

# %%
sns.barplot(df['retina'],df['Price'])
# Out:
# <AxesSubplot:xlabel='retina', ylabel='Price'>

# %%
df['Touchscreen']='null'
str='Touchscreen'
for i in range(1303):
    if str in df.ScreenResolution[i]:
        df['Touchscreen'][i]=1
    else:
        df['Touchscreen'][i]=0
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
sns.barplot(df['retina'],df['Price'])
# Out:
# <AxesSubplot:xlabel='retina', ylabel='Price'>

# %%
df['Hd']='null'
str='HD'
for i in range(1303):
    if str in df.ScreenResolution[i]:
        df['Hd'][i]=1
    else:
        df['Hd'][i]=0
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
sns.barplot(df['Hd'],df['Price'])
# Out:
# <AxesSubplot:xlabel='Hd', ylabel='Price'>

# %%
df
# Out:
#       Company TypeName  Inches                            ScreenResolution  \
# 0           1        4    13.3          IPS Panel Retina Display 2560x1600
# 1           1        4    13.3                                    1440x900
# 2           7        0    15.6                           Full HD 1920x1080
# 3           1        4    15.4          IPS Panel Retina Display 2880x1800
# 4           1        4    13.3          IPS Panel Retina Display 2560x1600
# ...       ...      ...     ...                                         ...
# 1298       10        3    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299       10        3    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300       10        0    14.0                                    1366x768
# 1301        7        0    15.6                                    1366x768
# 1302        2        0    15.6                                    1366x768
#
# ...

# %% [markdown]
# ## Hd is Correct column as has effect on price

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['Cpu'].unique()
# Out:
# array(['Intel Core i5 2.3GHz', 'Intel Core i5 1.8GHz',
#        'Intel Core i5 7200U 2.5GHz', 'Intel Core i7 2.7GHz',
#        'Intel Core i5 3.1GHz', 'AMD A9-Series 9420 3GHz',
#        'Intel Core i7 2.2GHz', 'Intel Core i7 8550U 1.8GHz',
#        'Intel Core i5 8250U 1.6GHz', 'Intel Core i3 6006U 2GHz',
#        'Intel Core i7 2.8GHz', 'Intel Core M m3 1.2GHz',
#        'Intel Core i7 7500U 2.7GHz', 'Intel Core i7 2.9GHz',
#        'Intel Core i3 7100U 2.4GHz', 'Intel Atom x5-Z8350 1.44GHz',
#        'Intel Core i5 7300HQ 2.5GHz', 'AMD E-Series E2-9000e 1.5GHz',
#        'Intel Core i5 1.6GHz', 'Intel Core i7 8650U 1.9GHz',
#        'Intel Atom x5-Z8300 1.44GHz', 'AMD E-Series E2-6110 1.5GHz',
#        'AMD A6-Series 9220 2.5GHz',
#        'Intel Celeron Dual Core N3350 1.1GHz',
#        'Intel Core i3 7130U 2.7GHz', 'Intel Core i7 7700HQ 2.8GHz',
#        'Intel Core i5 2.0GHz', 'AMD Ryzen 1700 3GHz',
#        'Intel Pentium Quad Core N4200 1.1GHz',
# ...

# %%
df['Processor']='null'
for i in range (1303):
    df['Processor'][i]=df['Cpu'][i].split()[:3]
    df['Processor'][i]=' '.join(df['Processor'][i])
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Processor'] = le.fit_transform(df['Processor'])

# %%
df['Clock_speed']='null'
for i in range (1303):
    df['Clock_speed'][i]=' '.join(df['Cpu'][i].split()[-1:])
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   int32
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
#  11  IPS               1303 non-null   object
#  12  x_axis            1303 non-null   object
#  13  y_axis            1303 non-null   int64
#  14  hd+               1303 non-null   int64
#  15  retina            1303 non-null   int64
# ...

# %%
df
# Out:
#       Company TypeName  Inches                            ScreenResolution  \
# 0           1        4    13.3          IPS Panel Retina Display 2560x1600
# 1           1        4    13.3                                    1440x900
# 2           7        0    15.6                           Full HD 1920x1080
# 3           1        4    15.4          IPS Panel Retina Display 2880x1800
# 4           1        4    13.3          IPS Panel Retina Display 2560x1600
# ...       ...      ...     ...                                         ...
# 1298       10        3    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299       10        3    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300       10        0    14.0                                    1366x768
# 1301        7        0    15.6                                    1366x768
# 1302        2        0    15.6                                    1366x768
#
# ...

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')
df['Clock_speed'] = df['Clock_speed'].str.replace('GHz','')
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')
df['Clock_speed'] = df['Clock_speed'].astype('float32')

df
# Out:
#       Company TypeName  Inches                            ScreenResolution  \
# 0           1        4    13.3          IPS Panel Retina Display 2560x1600
# 1           1        4    13.3                                    1440x900
# 2           7        0    15.6                           Full HD 1920x1080
# 3           1        4    15.4          IPS Panel Retina Display 2880x1800
# 4           1        4    13.3          IPS Panel Retina Display 2560x1600
# ...       ...      ...     ...                                         ...
# 1298       10        3    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299       10        3    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300       10        0    14.0                                    1366x768
# 1301        7        0    15.6                                    1366x768
# 1302        2        0    15.6                                    1366x768
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   int32
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  IPS               1303 non-null   object
#  12  x_axis            1303 non-null   object
#  13  y_axis            1303 non-null   int64
#  14  hd+               1303 non-null   int64
#  15  retina            1303 non-null   int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   int32
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  IPS               1303 non-null   object
#  12  x_axis            1303 non-null   object
#  13  y_axis            1303 non-null   int64
#  14  hd+               1303 non-null   int64
#  15  retina            1303 non-null   int64
# ...

# %%
df['x_axis']=df['x_axis'].astype(int)
df['IPS']=df['IPS'].astype(int)
df['Touchscreen']=df['Touchscreen'].astype(int)
df['Hd']=df['Hd'].astype(int)
# df['x_axis']=df['x_axis'].astype(int)

# %%
df['retina'].value_counts()
# Out:
# 0    1286
# 1      17
# Name: retina, dtype: int64

# %%
df.corr()['Price']
# Out:
# Company        0.140371
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# IPS            0.252208
# x_axis         0.556529
# y_axis         0.552809
# hd+            0.106643
# retina         0.087895
# Touchscreen    0.191226
# Hd             0.377209
# Processor      0.311499
# Clock_speed    0.430293
# Name: Price, dtype: float64

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['SSD']='0GB'
for i in range(1303):
    if "SSD" in df['Memory'][i]:
        df['SSD'][i]=df['Memory'][i].split()[:1]
        df['SSD'][i]=' '.join(df['SSD'][i])
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
for i in range(1303):
    if df['SSD'][i]=='1TB':
        df['SSD'][i]='1000GB'   # As 1 tb=1000gb
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df['SSD'] = df['SSD'].str.replace('GB','')
df['SSD'] = df['SSD'].astype('int32')

# %%
df.corr()['Price']
# Out:
# Company        0.140371
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# IPS            0.252208
# x_axis         0.556529
# y_axis         0.552809
# hd+            0.106643
# retina         0.087895
# Touchscreen    0.191226
# Hd             0.377209
# Processor      0.311499
# Clock_speed    0.430293
# SSD            0.676202
# Name: Price, dtype: float64

# %%
sns.barplot(df['SSD'],df['Price'])
# Out:
# <AxesSubplot:xlabel='SSD', ylabel='Price'>

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['Gpu_Company']='null'
for i in range (1303):
    df['Gpu_Company'][i]=df['Gpu'][i].split()[:1]
    df['Gpu_Company'][i]=' '.join(df['Gpu_Company'][i])
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df['Gpu_Company'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu_Company, dtype: int64

# %%
df=df[df['Gpu_Company']!='ARM']#Outlier removal
df = df.reset_index(drop=True)   # rearrange index from 0 to 1301

# %%
df['Gpu_Company'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu_Company, dtype: int64

# %%
#label encoding
for i in range(1302):    #not 1303 as 1 row is dropped
    if df['Gpu_Company'][i]=='Intel':
        df['Gpu_Company'][i]=0
    elif df['Gpu_Company'][i]=='Nvidia':
        df['Gpu_Company'][i]=1
    else:
        df['Gpu_Company'][i]=2
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
import matplotlib. pyplot as plt
sns.barplot(df['OpSys'],df['Price'])
plt.xticks(rotation='vertical')
plt.show()       #windows are combinable, mac , others -----> 3 categories

# %%
for i in range(1302):
    if df['OpSys'][i]=='macOS' or df['OpSys'][i]=='Mac OS X':
        df['OpSys'][i]=0
    elif df['OpSys'][i]=='Windows 10' or df['OpSys'][i]=='Windows 10 S' or df['OpSys'][i]=='Windows 7':
        df['OpSys'][i]=1
    else:
        df['OpSys'][i]=2
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df['OpSys'].value_counts()
# Out:
# 1    1125
# 2     156
# 0      21
# Name: OpSys, dtype: int64

# %%
df = df.drop(['ScreenResolution', 'Cpu','Memory','Gpu'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302 entries, 0 to 1301
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1302 non-null   int32
#  1   TypeName     1302 non-null   object
#  2   Inches       1302 non-null   float64
#  3   Ram          1302 non-null   int32
#  4   OpSys        1302 non-null   object
#  5   Weight       1302 non-null   float32
#  6   Price        1302 non-null   float64
#  7   IPS          1302 non-null   int32
#  8   x_axis       1302 non-null   int32
#  9   y_axis       1302 non-null   int64
#  10  hd+          1302 non-null   int64
#  11  retina       1302 non-null   int64
#  12  Touchscreen  1302 non-null   int32
#  13  Hd           1302 non-null   int32
#  14  Processor    1302 non-null   int32
#  15  Clock_speed  1302 non-null   float32
#  16  SSD          1302 non-null   int32
#  17  Gpu_Company  1302 non-null   object
# ...

# %%
df
# Out:
#       Company TypeName  Inches  Ram OpSys  Weight        Price  IPS  x_axis  \
# 0           1        4    13.3    8     0    1.37   71378.6832    1    2560
# 1           1        4    13.3    8     0    1.34   47895.5232    0    1440
# 2           7        0    15.6    8     2    1.86   30636.0000    0    1920
# 3           1        4    15.4   16     0    1.83  135195.3360    1    2880
# 4           1        4    13.3    8     0    1.37   96095.8080    1    2560
# ...       ...      ...     ...  ...   ...     ...          ...  ...     ...
# 1297       10        3    14.0    4     1    1.80   33992.6400    1    1920
# 1298       10        3    13.3   16     1    1.30   79866.7200    1    3200
# 1299       10        0    14.0    2     1    1.50   12201.1200    0    1366
# 1300        7        0    15.6    6     1    2.19   40705.9200    0    1366
# 1301        2        0    15.6    4     1    2.20   19660.3200    0    1366
#
# ...

# %%
df['OpSys'] = df['OpSys'].astype('int32')
df['Gpu_Company'] = df['Gpu_Company'].astype('int32')

# %%
df['TypeName'] = df['TypeName'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302 entries, 0 to 1301
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1302 non-null   int32
#  1   TypeName     1302 non-null   int32
#  2   Inches       1302 non-null   float64
#  3   Ram          1302 non-null   int32
#  4   OpSys        1302 non-null   int32
#  5   Weight       1302 non-null   float32
#  6   Price        1302 non-null   float64
#  7   IPS          1302 non-null   int32
#  8   x_axis       1302 non-null   int32
#  9   y_axis       1302 non-null   int64
#  10  hd+          1302 non-null   int64
#  11  retina       1302 non-null   int64
#  12  Touchscreen  1302 non-null   int32
#  13  Hd           1302 non-null   int32
#  14  Processor    1302 non-null   int32
#  15  Clock_speed  1302 non-null   float32
#  16  SSD          1302 non-null   int32
#  17  Gpu_Company  1302 non-null   int32
# ...

# %%
df.corr()['Price']
# Out:
# Company        0.141705
# TypeName       0.413884
# Inches         0.067329
# Ram            0.742905
# OpSys         -0.286904
# Weight         0.209867
# Price          1.000000
# IPS            0.253320
# x_axis         0.557369
# y_axis         0.554591
# hd+            0.106584
# retina         0.087852
# Touchscreen    0.192917
# Hd             0.376830
# Processor      0.312447
# Clock_speed    0.430122
# SSD            0.676066
# Gpu_Company    0.031881
# Name: Price, dtype: float64

# %%
sns.distplot(df['Weight'])
# Out:
# <AxesSubplot:xlabel='Weight'>

# %%
sns.distplot(df['Price'])
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
import numpy as np
x=df.drop(columns=['Price'])
y=np.log(df['Price'])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print("r2 score", r2_score(y_test,y_pred))
print("Mean Squared Error:", mse)
# Out:
# r2 score 0.7661084429644733
# Mean Squared Error: 0.08318048334305961

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=100, random_state=3,max_depth=16,max_features=0.75)
model.fit(x_train, y_train) 
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print("R2_score",r2_score(y_test,y_pred))
print("Mean Squared Error:", mse)
# Out:
# R2_score 0.8971455079477938
# Mean Squared Error: 0.036578859328418915

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(random_state=42)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print("R2_score",r2_score(y_test,y_pred))
print("Mean Squared Error:", mse)
# Out:
# R2_score 0.806204970057092
# Mean Squared Error: 0.0689206761648317

# %%
from sklearn.ensemble import GradientBoostingRegressor
model = GradientBoostingRegressor(random_state=42)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print("R2_score",r2_score(y_test,y_pred))
print("Mean Squared Error:", mse)
# Out:
# R2_score 0.8866857380788841
# Mean Squared Error: 0.04029874013292751

# %%
from sklearn.ensemble import AdaBoostRegressor
base_estimator = LinearRegression()
model = AdaBoostRegressor(base_estimator=base_estimator, n_estimators=100, random_state=42)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print("R2_score",r2_score(y_test,y_pred))
print("Mean Squared Error:", mse)
# Out:
# R2_score 0.7611205629102546
# Mean Squared Error: 0.0849543578643366
